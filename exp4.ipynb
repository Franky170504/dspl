# %% [markdown]
# Aim :- Implementation of regression analysis for selected data set.

# %% [markdown]
# LO :- LO4

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("breast_cancer.csv")

# %%
df
# Out:
#      Clump Thickness  Uniformity of Cell Size  ...  Mitoses  Class
# 0                  5                        1  ...        1      2
# 1                  5                        4  ...        1      2
# 2                  3                        1  ...        1      2
# 3                  6                        8  ...        1      2
# 4                  4                        1  ...        1      2
# ..               ...                      ...  ...      ...    ...
# 678                3                        1  ...        1      2
# 679                2                        1  ...        1      2
# 680                5                       10  ...        2      4
# 681                4                        8  ...        1      4
# 682                4                        8  ...        1      4
#
# [683 rows x 10 columns]

# %%
X = df.drop(columns=['Class'],axis=1)

# %%
X
# Out:
#      Clump Thickness  Uniformity of Cell Size  ...  Normal Nucleoli  Mitoses
# 0                  5                        1  ...                1        1
# 1                  5                        4  ...                2        1
# 2                  3                        1  ...                1        1
# 3                  6                        8  ...                7        1
# 4                  4                        1  ...                1        1
# ..               ...                      ...  ...              ...      ...
# 678                3                        1  ...                1        1
# 679                2                        1  ...                1        1
# 680                5                       10  ...               10        2
# 681                4                        8  ...                6        1
# 682                4                        8  ...                4        1
#
# [683 rows x 9 columns]

# %%
y = df['Class']

# %%
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 678    2
# 679    2
# 680    4
# 681    4
# 682    4
# Name: Class, Length: 683, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=42)
X_train.shape, X_test.shape
# Out:
# ((614, 9), (69, 9))

# %%
models = LogisticRegression()
models.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy",models.score(X_test,y_test)*100)
# Out:
# Accuracy 98.55072463768117

# %% [markdown]
# Conclusion:- This experiment applies regression on finding the stage of breast cancer

# %% [markdown]
# PO's :- PO1, PO2, PO3, PO4, PO4, PO5, PO8, PO9, PO10, PO12
